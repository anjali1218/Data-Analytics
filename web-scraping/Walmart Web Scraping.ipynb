# %% [markdown]
# !pip install bs4

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
# !pip install pandas

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
URL = "https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led"

# %%
#Headers for requests
HEADERS = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36' , 'Accept-Language': 'en-US,en;q=0.9'})

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
bsobj = BeautifulSoup(webpage.content, "html.parser")

# %%
bsobj
# Out:
# <!DOCTYPE html>
# ...

# %%
url_list = []
for i in range(2,26):
    url_list.append('https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led'+'&page='+str(i))
url_list
# Out:
# ['https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=2',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=3',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=4',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=5',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=6',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=7',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=8',
#  'https://www.walmart.com/search?q=shampoo+and+conditioner&typeahead=shampoo&affinityOverride=store_led&page=9',
# ...

# %%
item_names =[]
price_list =[]
item_ratings =[]
item_reviews =[]
shipping_details_list=[]

# %%
links
# Out:
# [<a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1"></a>,
#  <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">Skip to Main Content</a>,
#  <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu"><i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box"></i></a>,
#  <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile"><i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box"></i></a>,
# ...

# %%
link = links[10].get('href')

# %%
link
# Out:
# '/orders'

# %%
product_list = 'https://www.walmart.com' + link

# %%
product_list
# Out:
# 'https://www.walmart.com/orders'

# %%
bsobj.findAll('div',{'class':'h-100 pb1-xl pr4-xl pv1 ph1'})[0].span.text.strip()
# Out:
# 'Aussie Miracle Moist Shampoo and Conditioner Hair Set, 26.2 fl oz'

# %%
bsobj.findAll('div',{'class':'flex items-center mt2'})[0].span.next_sibling.next_sibling.text.split(" ")[5]
# Out:
# '512'

# %%
data = bsobj.findAll('span',{'class':'w_iUH7'})
data
# Out:
# [<span class="w_iUH7">Aussie Miracle Volume Shampoo and Conditioner Hair Set, All Hair Types, 26.2 fl oz  </span>,
#  <span class="w_iUH7">current price $13.47</span>,
#  <span class="w_iUH7">4.7 out of 5 Stars. 512 reviews</span>,
#  <span class="w_iUH7">Herbal Essences Argan Repair Shampoo and Conditioner, 13.5 fl oz Each  </span>,
#  <span class="w_iUH7">current price $12.97</span>,
#  <span class="w_iUH7">4.5 out of 5 Stars. 1722 reviews</span>,
#  <span class="w_iUH7">Aussie Miracle Moist Shampoo and Conditioner Hair Set, 26.2 fl oz  </span>,
#  <span class="w_iUH7">current price $13.47</span>,
#  <span class="w_iUH7">4.7 out of 5 Stars. 3157 reviews</span>,
#  <span class="w_iUH7">Herbal Essences Shampoo and Conditioner Set, All Hair Types, Rose Hips, 13.5 fl oz 2 Ct  </span>,
#  <span class="w_iUH7">current price $12.97</span>,
#  <span class="w_iUH7">4.7 out of 5 Stars. 2535 reviews</span>,
# ...

# %%
i = 0
n = len(data)
while(i<n):
    if data[i].text.startswith(("Available", "Was")):
        i+=1
    item_names.append(data[i].text.strip())
    i+=1
    if data[i].text.startswith(("Available", "Was")):
        i+=1
    price_list.append(data[i].text.split(" ")[-1])
    i+=1
    if data[i].text.startswith(("Available", "Was")):
        i+=1
    item_ratings.append(data[i].text.split(" ")[0])
    item_reviews.append(data[i].text.split(" ")[-2])
    i+=1

# %%
item_reviews
# Out:
# ['512',
#  '1722',
#  '3157',
#  '2535',
#  '3157',
#  '994',
#  '2606',
#  '1722',
#  '1839',
#  '1477',
#  '1243',
#  '3157',
#  '3753']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Product_Name':item_names, 'Price':price_list, 'Rating':item_ratings,'No_Of_Reviews':item_reviews}, 
                  columns=['Product_Name', 'Price', 'Rating', 'No_Of_Reviews'])

# %%
df.tail(5)
# Out:
#                                          Product_Name   Price Rating  \
# 8   Garnier Whole Blends Honey Treasures Shampoo a...   $6.97    4.7
# 9   Suave Moroccan Oil Infusion Shampoo and Condit...   $5.98    4.7
# 10  Dove Nourishing Rituals Coconut and Hydration ...   $7.48    4.6
# 11  Aussie Miracle Moist Shampoo and Conditioner H...  $13.47    4.7
# 12  TRESemme Luxurious Moisture Shampoo and Condit...   $9.98    4.7
#
#    No_Of_Reviews
# 8           1839
# 9           1477
# 10          1243
# 11          3157
# 12          3753
